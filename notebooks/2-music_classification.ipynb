# %%
import numpy as np 
import pandas as pd 

from pycaret.classification import *

# %%
music_data = pd.read_csv('../data/audio_data_genre_augmented.csv') 
music_data.head(5)
# Out:
#    label  zero_crossing_rate  zero_crossings  spectrogram  mel_spectrogram  \
# 0      0            0.083045         55031.0   -43.481335       -59.466248
# 1      0            0.056040         37139.0   -39.419030       -57.107990
# 2      0            0.076291         50563.0   -66.045040       -68.650800
# 3      0            0.033309         22077.0   -70.386650       -79.072080
# 4      0            0.101461         67225.0   -55.221130       -79.911285
#
#    harmonics  perceptual_shock_wave  spectral_centroids  \
# 0  -0.000049              -0.000011         1784.122641
# 1   0.000141              -0.000180         1530.261767
# 2  -0.000002              -0.000020         1552.832481
# 3   0.000004              -0.000018         1070.153418
# 4  -0.000018              -0.000010         1835.128513
#
#    spectral_centroids_delta  spectral_centroids_accelerate  ...  \
# 0                 -0.490523                      -0.061881  ...
# 1                  0.645964                      -0.085588  ...
# 2                  0.340027                       0.025039  ...
# 3                  0.251255                       0.079369  ...
# 4                 -0.172070                      -0.245268  ...
#
#    mfcc_accelerate_9     mfcc10  mfcc_delta_10  mfcc_accelerate_10    mfcc11  \
# 0       4.187489e-03  -8.326061      -0.002930            0.004329  8.802088
# 1      -8.625205e-03  -5.558824      -0.006495            0.000426  5.377876
# 2      -2.788004e-07 -13.125314      -0.006027           -0.005649  5.791246
# 3      -8.826724e-04  -3.200026      -0.010480           -0.003420  6.078082
# 4      -3.368575e-03 -13.084959       0.002908            0.001244 -2.810499
#
#    mfcc_delta_11  mfcc_accelerate_11    mfcc12  mfcc_delta_12  \
# 0       0.002346           -0.004537 -3.669941       0.000569
# 1      -0.004285           -0.006501 -2.234492       0.008674
# 2      -0.002034           -0.002225 -8.901966       0.005649
# 3      -0.009716            0.001235 -2.478445      -0.002598
# 4       0.003760            0.001076 -6.934471      -0.018504
#
#    mfcc_accelerate_12
# 0           -0.004123
# 1            0.000504
# 2           -0.000031
# 3           -0.000736
# 4           -0.000860
#
# [5 rows x 67 columns]

# %%
def find_best_classifier(dataframe, target_column):
    clf = setup(data = dataframe, target = target_column, feature_selection=True)
    best_model = compare_models()
    return best_model

# %%
best_model = find_best_classifier(music_data, 'label')
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002805 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 16604
# [LightGBM] [Info] Number of data points in the train set: 1008, number of used features: 66
# [LightGBM] [Info] Start training from score -2.290751
# [LightGBM] [Info] Start training from score -2.361847
# [LightGBM] [Info] Start training from score -2.252284
# [LightGBM] [Info] Start training from score -2.252284
# [LightGBM] [Info] Start training from score -2.383124
# [LightGBM] [Info] Start training from score -2.252284
# [LightGBM] [Info] Start training from score -2.261763
# [LightGBM] [Info] Start training from score -2.427087
# [LightGBM] [Info] Start training from score -2.341012
# [LightGBM] [Info] Start training from score -2.224376
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# <style type="text/css">
# #T_240d7_row8_col1, #T_240d7_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_240d7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_240d7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_240d7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_240d7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_240d7_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_240d7_row0_col1" class="data row0 col1" >7695</td>
#     </tr>
#     <tr>
#       <th id="T_240d7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_240d7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_240d7_row1_col1" class="data row1 col1" >label</td>
#     </tr>
#     <tr>
#       <th id="T_240d7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_240d7_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_240d7_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_240d7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_240d7_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_240d7_row3_col1" class="data row3 col1" >(1441, 67)</td>
#     </tr>
#     <tr>
#       <th id="T_240d7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_240d7_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_240d7_row4_col1" class="data row4 col1" >(1441, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_240d7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_240d7_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_240d7_row5_col1" class="data row5 col1" >(1008, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_240d7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_240d7_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_240d7_row6_col1" class="data row6 col1" >(433, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_240d7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_240d7_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_240d7_row7_col1" class="data row7 col1" >66</td>
#     </tr>
#     <tr>
#       <th id="T_240d7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_240d7_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_240d7_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_240d7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_240d7_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_240d7_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_240d7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_240d7_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_240d7_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_240d7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_240d7_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_240d7_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_240d7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_240d7_row12_col0" class="data row12 col0" >Feature selection</td>
#       <td id="T_240d7_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_240d7_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_240d7_row13_col0" class="data row13 col0" >Feature selection method</td>
#       <td id="T_240d7_row13_col1" class="data row13 col1" >classic</td>
#     </tr>
#     <tr>
#       <th id="T_240d7_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_240d7_row14_col0" class="data row14 col0" >Feature selection estimator</td>
#       <td id="T_240d7_row14_col1" class="data row14 col1" >lightgbm</td>
#     </tr>
#     <tr>
#       <th id="T_240d7_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_240d7_row15_col0" class="data row15 col0" >Number of features selected</td>
#       <td id="T_240d7_row15_col1" class="data row15 col1" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_240d7_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_240d7_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_240d7_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_240d7_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_240d7_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_240d7_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_240d7_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_240d7_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_240d7_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_240d7_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_240d7_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_240d7_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_240d7_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_240d7_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_240d7_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_240d7_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_240d7_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_240d7_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_240d7_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_240d7_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_240d7_row22_col1" class="data row22 col1" >198e</td>
#     </tr>
#   </tbody>
# </table>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             09:53:24
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  CatBoost Classifier
# <style type="text/css">
# #T_2e7e2 th {
#   text-align: left;
# }
# #T_2e7e2_row0_col0, #T_2e7e2_row0_col1, #T_2e7e2_row0_col2, #T_2e7e2_row0_col3, #T_2e7e2_row0_col4, #T_2e7e2_row0_col5, #T_2e7e2_row0_col6, #T_2e7e2_row0_col7, #T_2e7e2_row0_col8, #T_2e7e2_row1_col0, #T_2e7e2_row1_col1, #T_2e7e2_row1_col2, #T_2e7e2_row1_col3, #T_2e7e2_row1_col4, #T_2e7e2_row1_col5, #T_2e7e2_row1_col6, #T_2e7e2_row1_col7, #T_2e7e2_row1_col8, #T_2e7e2_row2_col0, #T_2e7e2_row2_col1, #T_2e7e2_row2_col2, #T_2e7e2_row2_col3, #T_2e7e2_row2_col4, #T_2e7e2_row2_col5, #T_2e7e2_row2_col6, #T_2e7e2_row2_col7, #T_2e7e2_row2_col8, #T_2e7e2_row3_col0, #T_2e7e2_row3_col1, #T_2e7e2_row3_col2, #T_2e7e2_row3_col3, #T_2e7e2_row3_col4, #T_2e7e2_row3_col5, #T_2e7e2_row3_col6, #T_2e7e2_row3_col7, #T_2e7e2_row3_col8, #T_2e7e2_row4_col0, #T_2e7e2_row4_col1, #T_2e7e2_row4_col2, #T_2e7e2_row4_col3, #T_2e7e2_row4_col4, #T_2e7e2_row4_col5, #T_2e7e2_row4_col6, #T_2e7e2_row4_col7, #T_2e7e2_row4_col8, #T_2e7e2_row5_col0, #T_2e7e2_row5_col1, #T_2e7e2_row5_col2, #T_2e7e2_row5_col3, #T_2e7e2_row5_col4, #T_2e7e2_row5_col5, #T_2e7e2_row5_col6, #T_2e7e2_row5_col7, #T_2e7e2_row5_col8, #T_2e7e2_row6_col0, #T_2e7e2_row6_col1, #T_2e7e2_row6_col2, #T_2e7e2_row6_col3, #T_2e7e2_row6_col4, #T_2e7e2_row6_col5, #T_2e7e2_row6_col6, #T_2e7e2_row6_col7, #T_2e7e2_row6_col8, #T_2e7e2_row7_col0, #T_2e7e2_row7_col1, #T_2e7e2_row7_col2, #T_2e7e2_row7_col3, #T_2e7e2_row7_col4, #T_2e7e2_row7_col5, #T_2e7e2_row7_col6, #T_2e7e2_row7_col7, #T_2e7e2_row7_col8, #T_2e7e2_row8_col0, #T_2e7e2_row8_col1, #T_2e7e2_row8_col2, #T_2e7e2_row8_col3, #T_2e7e2_row8_col4, #T_2e7e2_row8_col5, #T_2e7e2_row8_col6, #T_2e7e2_row8_col7, #T_2e7e2_row8_col8, #T_2e7e2_row9_col0, #T_2e7e2_row9_col1, #T_2e7e2_row9_col2, #T_2e7e2_row9_col3, #T_2e7e2_row9_col4, #T_2e7e2_row9_col5, #T_2e7e2_row9_col6, #T_2e7e2_row9_col7, #T_2e7e2_row9_col8, #T_2e7e2_row10_col0, #T_2e7e2_row10_col1, #T_2e7e2_row10_col2, #T_2e7e2_row10_col3, #T_2e7e2_row10_col4, #T_2e7e2_row10_col5, #T_2e7e2_row10_col6, #T_2e7e2_row10_col7, #T_2e7e2_row10_col8, #T_2e7e2_row11_col0, #T_2e7e2_row11_col1, #T_2e7e2_row11_col2, #T_2e7e2_row11_col3, #T_2e7e2_row11_col4, #T_2e7e2_row11_col5, #T_2e7e2_row11_col6, #T_2e7e2_row11_col7, #T_2e7e2_row11_col8, #T_2e7e2_row12_col0, #T_2e7e2_row12_col1, #T_2e7e2_row12_col2, #T_2e7e2_row12_col3, #T_2e7e2_row12_col4, #T_2e7e2_row12_col5, #T_2e7e2_row12_col6, #T_2e7e2_row12_col7, #T_2e7e2_row12_col8, #T_2e7e2_row13_col0, #T_2e7e2_row13_col1, #T_2e7e2_row13_col2, #T_2e7e2_row13_col3, #T_2e7e2_row13_col4, #T_2e7e2_row13_col5, #T_2e7e2_row13_col6, #T_2e7e2_row13_col7, #T_2e7e2_row13_col8 {
#   text-align: left;
# }
# </style>
# <table id="T_2e7e2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e7e2_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_2e7e2_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_2e7e2_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_2e7e2_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_2e7e2_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_2e7e2_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_2e7e2_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_2e7e2_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_2e7e2_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e7e2_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_2e7e2_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_2e7e2_row0_col1" class="data row0 col1" >0.8205</td>
#       <td id="T_2e7e2_row0_col2" class="data row0 col2" >0.9790</td>
#       <td id="T_2e7e2_row0_col3" class="data row0 col3" >0.8205</td>
#       <td id="T_2e7e2_row0_col4" class="data row0 col4" >0.8329</td>
#       <td id="T_2e7e2_row0_col5" class="data row0 col5" >0.8186</td>
#       <td id="T_2e7e2_row0_col6" class="data row0 col6" >0.8005</td>
#       <td id="T_2e7e2_row0_col7" class="data row0 col7" >0.8020</td>
#       <td id="T_2e7e2_row0_col8" class="data row0 col8" >3.6450</td>
#     </tr>
#     <tr>
#       <th id="T_2e7e2_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_2e7e2_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_2e7e2_row1_col1" class="data row1 col1" >0.8017</td>
#       <td id="T_2e7e2_row1_col2" class="data row1 col2" >0.9756</td>
#       <td id="T_2e7e2_row1_col3" class="data row1 col3" >0.8017</td>
#       <td id="T_2e7e2_row1_col4" class="data row1 col4" >0.8139</td>
#       <td id="T_2e7e2_row1_col5" class="data row1 col5" >0.7991</td>
#       <td id="T_2e7e2_row1_col6" class="data row1 col6" >0.7796</td>
#       <td id="T_2e7e2_row1_col7" class="data row1 col7" >0.7815</td>
#       <td id="T_2e7e2_row1_col8" class="data row1 col8" >4.9350</td>
#     </tr>
#     <tr>
#       <th id="T_2e7e2_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_2e7e2_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_2e7e2_row2_col1" class="data row2 col1" >0.7967</td>
#       <td id="T_2e7e2_row2_col2" class="data row2 col2" >0.9757</td>
#       <td id="T_2e7e2_row2_col3" class="data row2 col3" >0.7967</td>
#       <td id="T_2e7e2_row2_col4" class="data row2 col4" >0.8138</td>
#       <td id="T_2e7e2_row2_col5" class="data row2 col5" >0.7959</td>
#       <td id="T_2e7e2_row2_col6" class="data row2 col6" >0.7740</td>
#       <td id="T_2e7e2_row2_col7" class="data row2 col7" >0.7759</td>
#       <td id="T_2e7e2_row2_col8" class="data row2 col8" >3.6060</td>
#     </tr>
#     <tr>
#       <th id="T_2e7e2_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_2e7e2_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_2e7e2_row3_col1" class="data row3 col1" >0.7917</td>
#       <td id="T_2e7e2_row3_col2" class="data row3 col2" >0.9750</td>
#       <td id="T_2e7e2_row3_col3" class="data row3 col3" >0.7917</td>
#       <td id="T_2e7e2_row3_col4" class="data row3 col4" >0.8071</td>
#       <td id="T_2e7e2_row3_col5" class="data row3 col5" >0.7897</td>
#       <td id="T_2e7e2_row3_col6" class="data row3 col6" >0.7685</td>
#       <td id="T_2e7e2_row3_col7" class="data row3 col7" >0.7703</td>
#       <td id="T_2e7e2_row3_col8" class="data row3 col8" >3.7230</td>
#     </tr>
#     <tr>
#       <th id="T_2e7e2_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_2e7e2_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_2e7e2_row4_col1" class="data row4 col1" >0.7848</td>
#       <td id="T_2e7e2_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_2e7e2_row4_col3" class="data row4 col3" >0.7848</td>
#       <td id="T_2e7e2_row4_col4" class="data row4 col4" >0.7993</td>
#       <td id="T_2e7e2_row4_col5" class="data row4 col5" >0.7833</td>
#       <td id="T_2e7e2_row4_col6" class="data row4 col6" >0.7608</td>
#       <td id="T_2e7e2_row4_col7" class="data row4 col7" >0.7625</td>
#       <td id="T_2e7e2_row4_col8" class="data row4 col8" >5.8600</td>
#     </tr>
#     <tr>
#       <th id="T_2e7e2_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_2e7e2_row5_col0" class="data row5 col0" >Decision Tree Classifier</td>
#       <td id="T_2e7e2_row5_col1" class="data row5 col1" >0.7094</td>
#       <td id="T_2e7e2_row5_col2" class="data row5 col2" >0.8383</td>
#       <td id="T_2e7e2_row5_col3" class="data row5 col3" >0.7094</td>
#       <td id="T_2e7e2_row5_col4" class="data row5 col4" >0.7219</td>
#       <td id="T_2e7e2_row5_col5" class="data row5 col5" >0.7089</td>
#       <td id="T_2e7e2_row5_col6" class="data row5 col6" >0.6768</td>
#       <td id="T_2e7e2_row5_col7" class="data row5 col7" >0.6783</td>
#       <td id="T_2e7e2_row5_col8" class="data row5 col8" >2.9260</td>
#     </tr>
#     <tr>
#       <th id="T_2e7e2_level0_row6" class="row_heading level0 row6" >qda</th>
#       <td id="
# Processing:   0%|          | 0/69 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18764\917780821.py in <cell line: 1>()
# ----> 1 best_model = find_best_classifier(music_data, 'label')
#
# ~\AppData\Local\Temp\ipykernel_18764\1892478640.py in find_best_classifier(dataframe, target_column)
#       1 def find_best_classifier(dataframe, target_column):
#       2     clf = setup(data = dataframe, target = target_column, feature_selection=True)
# ----> 3     best_model = compare_models()
#       4     return best_model
#
# c:\Users\pedro.mira\AppData\Local\miniconda3\envs\felipe_cd\lib\site-packages\pycaret\utils\generic.py in wrapper(*args, **kwargs)
#     962                 if globals_d[name] is None:
#     963                     raise ValueError(message)
# --> 964             return func(*args, **kwargs)
#     965
#     966         return wrapper
#
# c:\Users\pedro.mira\AppData\Local\miniconda3\envs\felipe_cd\lib\site-packages\pycaret\classification\functional.py in compare_models(include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, engine, verbose, parallel)
#     812     """
#     813
# --> 814     return _CURRENT_EXPERIMENT.compare_models(
#     815         include=include,
#     816         exclude=exclude,
#
# c:\Users\pedro.mira\AppData\Local\miniconda3\envs\felipe_cd\lib\site-packages\pycaret\classification\oop.py in compare_models(self, include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, engine, verbose, parallel)
#    1178
#    1179         try:
# -> 1180             return_values = super().compare_models(
#    1181                 include=include,
#    1182                 exclude=exclude,
#
# c:\Users\pedro.mira\AppData\Local\miniconda3\envs\felipe_cd\lib\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py in compare_models(self, include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, verbose, parallel, caller_params)
#     792
#     793             try:
# --> 794                 model, model_fit_time = self._create_model(**create_model_args)
#     795                 model_results = self.pull(pop=True)
#     796                 assert (
#
# c:\Users\pedro.mira\AppData\Local\miniconda3\envs\felipe_cd\lib\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py in _create_model(self, estimator, fold, round, cross_validation, predict, fit_kwargs, groups, refit, probability_threshold, experiment_custom_tags, verbose, system, add_to_model_list, X_train_data, y_train_data, metrics, display, model_only, return_train_score, error_score, **kwargs)
#    1531             return model
#    1532
# -> 1533         model, model_fit_time, model_results, _ = self._create_model_with_cv(
#    1534             model=model,
#    1535             data_X=data_X,
#
# c:\Users\pedro.mira\AppData\Local\miniconda3\envs\felipe_cd\lib\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py in _create_model_with_cv(self, model, data_X, data_y, fit_kwargs, round, cv, groups, metrics, refit, system, display, error_score, return_train_score)
#    1124                 model_fit_start = time.time()
#    1125                 with redirect_output(self.logger):
# -> 1126                     scores = cross_validate(
#    1127                         pipeline_with_model,
#    1128                         data_X,
#
# c:\Users\pedro.mira\AppData\Local\miniconda3\envs\felipe_cd\lib\site-packages\sklearn\utils\_param_validation.py in wrapper(*args, **kwargs)
#     211                     )
#     212                 ):
# --> 213                     return func(*args, **kwargs)
#     214             except InvalidParameterError as e:
#     215                 # When the function is just a wrapper around an estimator, we allow
#
# c:\Users\pedro.mira\AppData\Local\miniconda3\envs\felipe_cd\lib\site-packages\sklearn\model_selection\_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     428     # independent, and that it is pickle-able.
#     429     parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 430     results = parallel(
#     431         delayed(_fit_and_score)(
#     432             clone(estimator),
#
# c:\Users\pedro.mira\AppData\Local\miniconda3\envs\felipe_cd\lib\site-packages\sklearn\utils\parallel.py in __call__(self, iterable)
#      65             for delayed_func, args, kwargs in iterable
#      66         )
# ---> 67         return super().__call__(iterable_with_config)
#      68
#      69
#
# ~\AppData\Roaming\Python\Python310\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1096
#    1097             with self._backend.retrieval_context():
# -> 1098                 self.retrieve()
#    1099             # Make sure that we get a last message telling us we are done
#    1100             elapsed_time = time.time() - self._start_time
#
# ~\AppData\Roaming\Python\Python310\site-packages\joblib\parallel.py in retrieve(self)
#     973             try:
#     974                 if getattr(self._backend, 'supports_timeout', False):
# --> 975                     self._output.extend(job.get(timeout=self.timeout))
#     976                 else:
#     977                     self._output.extend(job.get())
#
# ~\AppData\Roaming\Python\Python310\site-packages\joblib\_parallel_backends.py in wrap_future_result(future, timeout)
#     565         AsyncResults.get from multiprocessing."""
#     566         try:
# --> 567             return future.result(timeout=timeout)
#     568         except CfTimeoutError as e:
#     569             raise TimeoutError from e
#
# c:\Users\pedro.mira\AppData\Local\miniconda3\envs\felipe_cd\lib\concurrent\futures\_base.py in result(self, timeout)
#     451                     return self.__get_result()
#     452
# --> 453                 self._condition.wait(timeout)
#     454
#     455                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# c:\Users\pedro.mira\AppData\Local\miniconda3\envs\felipe_cd\lib\threading.py in wait(self, timeout)
#     318         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319             if timeout is None:
# --> 320                 waiter.acquire()
#     321                 gotit = True
#     322             else:
#
# KeyboardInterrupt:

# %%
print(best_model)

# %%
save_model(best_model, 'best_model')
